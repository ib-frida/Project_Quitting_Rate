# %% [markdown]
# # Para el caso de nuestro trabajo
#
# Usando el API de Kaggle para descargar le dataset del siguiente URL 'https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset'

# %%
pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\ifrid\anaconda3\lib\site-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in c:\users\ifrid\anaconda3\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in c:\users\ifrid\anaconda3\lib\site-packages (from kaggle) (2024.6.2)
# Requirement already satisfied: python-dateutil in c:\users\ifrid\anaconda3\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: requests in c:\users\ifrid\anaconda3\lib\site-packages (from kaggle) (2.32.2)
# Requirement already satisfied: tqdm in c:\users\ifrid\anaconda3\lib\site-packages (from kaggle) (4.66.4)
# Requirement already satisfied: python-slugify in c:\users\ifrid\anaconda3\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: urllib3 in c:\users\ifrid\anaconda3\lib\site-packages (from kaggle) (2.2.2)
# Requirement already satisfied: bleach in c:\users\ifrid\anaconda3\lib\site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: packaging in c:\users\ifrid\anaconda3\lib\site-packages (from bleach->kaggle) (23.2)
# Requirement already satisfied: webencodings in c:\users\ifrid\anaconda3\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\ifrid\anaconda3\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ifrid\anaconda3\lib\site-packages (from requests->kaggle) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ifrid\anaconda3\lib\site-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: colorama in c:\users\ifrid\anaconda3\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Comando de API de Kaggle descrito en su documentación
# Doc de la API ---> "https://www.kaggle.com/docs/api#creating-and-maintaining-datasets"
# !kaggle datasets download -d pavansubhasht/ibm-hr-analytics-attrition-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset
# License(s): DbCL-1.0
# ibm-hr-analytics-attrition-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile

# Nombre del archivo ZIP
zip_file = 'ibm-hr-analytics-attrition-dataset.zip'

# Descomprimir el archivo
with zipfile.ZipFile(zip_file, 'r') as zip_ref:
    zip_ref.extractall()

# %%
# Importamos pandas para trabajar con DataFrames

import pandas as pd
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# Visualizar
# Opcional en terminal print(df)
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
# Verificar si hay valores NaN en alguna columna

df.isnull().any()
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# Over18                      False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# StockOptionLevel            False
# TotalWorkingYears           False
# TrainingTimesLastYear       False
# WorkLifeBalance             False
# YearsAtCompany              False
# YearsInCurrentRole          False
# YearsSinceLastPromotion     False
# YearsWithCurrManager        False
# dtype: bool

# %% [markdown]
# Resultados Preliminares
#
# 1.- la salida indica que no hay valores faltantes (NaN) en ninguna de las columnas del DataFrame, ya que todas las columnas tienen el valor False asociado. Esto significa que todas las columnas están completamente llenas de datos, sin valores nulos o faltantes.
#
# 2.- Por lo tanto, no hay ningún procedimiento para aplicar sobre los NaNs.
#
# 3.- Por lo tanto, el dataset ya esta limpio.
#
# 4.- Por lo tanto, el dataset no necesita ser re-indexado.
#
# 5.- Lo que sí podemos hacer es renombrarlas al español para que sean más amigables con hispanoparlantes.

# %%
# Columnas en el DataFrame
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Renombrar las columnas y re-asignar

df = df.rename(columns={
    'Age': 'Edad', 
    'Attrition': 'Renuncia', 
    'BusinessTravel': 'Viaje_de_Negocios', 
    'DailyRate': 'Tasa_Diaria', 
    'Department': 'Departamento', 
    'DistanceFromHome': 'Distancia_Desde_Casa', 
    'Education': 'Educación', 
    'EducationField': 'Campo_de_Educación', 
    'EmployeeCount': 'Conteo_de_Empleados', 
    'EmployeeNumber': 'Número_de_Empleado', 
    'EnvironmentSatisfaction': 'Satisfacción_del_Entorno', 
    'Gender': 'Género', 
    'HourlyRate': 'Tasa_por_Hora', 
    'JobInvolvement': 'Involucramiento_en_el_Trabajo', 
    'JobLevel': 'Nivel_de_Trabajo', 
    'JobRole': 'Rol_de_Trabajo', 
    'JobSatisfaction': 'Satisfacción_en_el_Trabajo', 
    'MaritalStatus': 'Estado_Civil', 
    'MonthlyIncome': 'Ingreso_Mensual', 
    'MonthlyRate': 'Tasa_Mensual', 
    'NumCompaniesWorked': 'Número_de_Empresas_Trabajadas', 
    'Over18': 'Mayor_de_18', 
    'OverTime': 'Horas_Extra', 
    'PercentSalaryHike': 'Incremento_porcentual_de_Salario', 
    'PerformanceRating': 'Calificación_de_Rendimiento', 
    'RelationshipSatisfaction': 'Satisfacción_en_las_Relaciones', 
    'StandardHours': 'Horas_Estándar', 
    'StockOptionLevel': 'Nivel_de_Acciones', 
    'TotalWorkingYears': 'Total_de_Años_Trabajados', 
    'TrainingTimesLastYear': 'Veces_de_Capacitación_Último_Año', 
    'WorkLifeBalance': 'Equilibrio_Vida_Trabajo', 
    'YearsAtCompany': 'Años_en_la_Empresa', 
    'YearsInCurrentRole': 'Años_en_el_Rol_Actual', 
    'YearsSinceLastPromotion': 'Años_desde_Última_Promoción', 
    'YearsWithCurrManager': 'Años_con_el_Gerente_Actual'
})

# %%
df
# Out:
#       Edad Renuncia  Viaje_de_Negocios  Tasa_Diaria            Departamento  \
# 0       41      Yes      Travel_Rarely         1102                   Sales
# 1       49       No  Travel_Frequently          279  Research & Development
# 2       37      Yes      Travel_Rarely         1373  Research & Development
# 3       33       No  Travel_Frequently         1392  Research & Development
# 4       27       No      Travel_Rarely          591  Research & Development
# ...    ...      ...                ...          ...                     ...
# 1465    36       No  Travel_Frequently          884  Research & Development
# 1466    39       No      Travel_Rarely          613  Research & Development
# 1467    27       No      Travel_Rarely          155  Research & Development
# 1468    49       No  Travel_Frequently         1023                   Sales
# 1469    34       No      Travel_Rarely          628  Research & Development
#
#       Distancia_Desde_Casa  Educación Campo_de_Educación  Conteo_de_Empleados  \
# 0                        1          2      Life Sciences                    1
# 1                        8          1      Life Sciences                    1
# 2                        2          2              Other                    1
# 3                        3          4      Life Sciences                    1
# 4                        2          1            Medical                    1
# ...                    ...        ...                ...                  ...
# 1465                    23          2            Medical                    1
# 1466                     6          1            Medical                    1
# 1467                     4          3      Life Sciences                    1
# 1468                     2          3            Medical                    1
# 1469                     8          3            Medical                    1
#
#       Número_de_Empleado  ...  Satisfacción_en_las_Relaciones Horas_Estándar  \
# 0                      1  ...                               1             80
# 1                      2  ...                               4             80
# 2                      4  ...                               2             80
# 3                      5  ...                               3             80
# 4                      7  ...                               4             80
# ...                  ...  ...                             ...            ...
# 1465                2061  ...                               3             80
# 1466                2062  ...                               1             80
# 1467                2064  ...                               2             80
# 1468                2065  ...                               4             80
# 1469                2068  ...                               1             80
#
#       Nivel_de_Acciones  Total_de_Años_Trabajados  \
# 0                     0                         8
# 1                     1                        10
# 2                     0                         7
# 3                     0                         8
# 4                     1                         6
# ...                 ...                       ...
# 1465                  1                        17
# 1466                  1                         9
# 1467                  1                         6
# 1468                  0                        17
# 1469                  0                         6
#
#       Veces_de_Capacitación_Último_Año Equilibrio_Vida_Trabajo  \
# 0                                    0                       1
# 1                                    3                       3
# 2                                    3                       3
# 3                                    3                       3
# 4                                    3                       3
# ...                                ...                     ...
# 1465                                 3                       3
# 1466                                 5                       3
# 1467                                 0                       3
# 1468                                 3                       2
# 1469                                 3                       4
#
#       Años_en_la_Empresa Años_en_el_Rol_Actual  Años_desde_Última_Promoción  \
# 0                      6                     4                            0
# 1                     10                     7                            1
# 2                      0                     0                            0
# 3                      8                     7                            3
# 4                      2                     2                            2
# ...                  ...                   ...                          ...
# 1465                   5                     2                            0
# 1466                   7                     7                            1
# 1467                   6                     2                            0
# 1468                   9                     6                            0
# 1469                   4                     3                            1
#
#       Años_con_el_Gerente_Actual
# 0                              5
# 1                              7
# 2                              0
# 3                              0
# 4                              2
# ...                          ...
# 1465                           3
# 1466                           7
# 1467                           3
# 1468                           8
# 1469                           2
#
# [1470 rows x 35 columns]

# %%
# Para el caso de la columna "Departamento"
df.Departamento.unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df['Departamento'] = df['Departamento'].replace({
    'Sales': 'Ventas',
    'Research & Development': 'Investigación y Desarrollo',
    'Human Resources': 'Recursos Humanos'
})

# %%
# Para el caso de la columna "Campo_de_Educación"
df.Campo_de_Educación.unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
df['Campo_de_Educación'] = df['Campo_de_Educación'].replace({
    'Life Sciences': 'Ciencias de la Vida',
    'Other': 'Otro',
    'Medical': 'Medicina',
    'Marketing': 'Mercadeo',
    'Technical Degree': 'Título Técnico',
    'Human Resources': 'Recursos Humanos'
})

# %%
# Para el caso de la columna "Viaje_de_Negocios"
df.Viaje_de_Negocios.unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
df['Viaje_de_Negocios'] = df['Viaje_de_Negocios'].replace({
    'Travel_Rarely': 'Viaja Raramente',
    'Travel_Frequently': 'Viaja Frecuentemente',
    'Non-Travel': 'No Viaja'
})

# %%
# Por último para el caso de "Renuncia"
df.Renuncia.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Renuncia'] = df['Renuncia'].replace({
    'Yes': 'Sí',
    'No': 'No'
})

# %%
# Por ultimo en este apartado visualizamos el DataFrame y opcionalmente lo guardamos

df

# df.to_csv("datos_bedu_proyecto.csv",index=False)
# Out:
#       Edad Renuncia     Viaje_de_Negocios  Tasa_Diaria  \
# 0       41       Sí       Viaja Raramente         1102
# 1       49       No  Viaja Frecuentemente          279
# 2       37       Sí       Viaja Raramente         1373
# 3       33       No  Viaja Frecuentemente         1392
# 4       27       No       Viaja Raramente          591
# ...    ...      ...                   ...          ...
# 1465    36       No  Viaja Frecuentemente          884
# 1466    39       No       Viaja Raramente          613
# 1467    27       No       Viaja Raramente          155
# 1468    49       No  Viaja Frecuentemente         1023
# 1469    34       No       Viaja Raramente          628
#
#                     Departamento  Distancia_Desde_Casa  Educación  \
# 0                         Ventas                     1          2
# 1     Investigación y Desarrollo                     8          1
# 2     Investigación y Desarrollo                     2          2
# 3     Investigación y Desarrollo                     3          4
# 4     Investigación y Desarrollo                     2          1
# ...                          ...                   ...        ...
# 1465  Investigación y Desarrollo                    23          2
# 1466  Investigación y Desarrollo                     6          1
# 1467  Investigación y Desarrollo                     4          3
# 1468                      Ventas                     2          3
# 1469  Investigación y Desarrollo                     8          3
#
#        Campo_de_Educación  Conteo_de_Empleados  Número_de_Empleado  ...  \
# 0     Ciencias de la Vida                    1                   1  ...
# 1     Ciencias de la Vida                    1                   2  ...
# 2                    Otro                    1                   4  ...
# 3     Ciencias de la Vida                    1                   5  ...
# 4                Medicina                    1                   7  ...
# ...                   ...                  ...                 ...  ...
# 1465             Medicina                    1                2061  ...
# 1466             Medicina                    1                2062  ...
# 1467  Ciencias de la Vida                    1                2064  ...
# 1468             Medicina                    1                2065  ...
# 1469             Medicina                    1                2068  ...
#
#       Satisfacción_en_las_Relaciones Horas_Estándar  Nivel_de_Acciones  \
# 0                                  1             80                  0
# 1                                  4             80                  1
# 2                                  2             80                  0
# 3                                  3             80                  0
# 4                                  4             80                  1
# ...                              ...            ...                ...
# 1465                               3             80                  1
# 1466                               1             80                  1
# 1467                               2             80                  1
# 1468                               4             80                  0
# 1469                               1             80                  0
#
#       Total_de_Años_Trabajados  Veces_de_Capacitación_Último_Año  \
# 0                            8                                 0
# 1                           10                                 3
# 2                            7                                 3
# 3                            8                                 3
# 4                            6                                 3
# ...                        ...                               ...
# 1465                        17                                 3
# 1466                         9                                 5
# 1467                         6                                 0
# 1468                        17                                 3
# 1469                         6                                 3
#
#      Equilibrio_Vida_Trabajo  Años_en_la_Empresa Años_en_el_Rol_Actual  \
# 0                          1                   6                     4
# 1                          3                  10                     7
# 2                          3                   0                     0
# 3                          3                   8                     7
# 4                          3                   2                     2
# ...                      ...                 ...                   ...
# 1465                       3                   5                     2
# 1466                       3                   7                     7
# 1467                       3                   6                     2
# 1468                       2                   9                     6
# 1469                       4                   4                     3
#
#       Años_desde_Última_Promoción  Años_con_el_Gerente_Actual
# 0                               0                           5
# 1                               1                           7
# 2                               0                           0
# 3                               3                           0
# 4                               2                           2
# ...                           ...                         ...
# 1465                            0                           3
# 1466                            1                           7
# 1467                            0                           3
# 1468                            0                           8
# 1469                            1                           2
#
# [1470 rows x 35 columns]
